# %% [markdown]
# # 220329 Simulating Clusters with Continuous and Categorical Variables

# %%
R.Version()
# Out:
# $platform
# [1] "x86_64-apple-darwin13.4.0"
#
# $arch
# [1] "x86_64"
#
# $os
# [1] "darwin13.4.0"
#
# $system
# [1] "x86_64, darwin13.4.0"
#
# $status
# [1] ""
#
# $major
# [1] "3"
#
# $minor
# [1] "6.1"
#
# $year
# [1] "2019"
#
# $month
# [1] "07"
#
# $day
# [1] "05"
#
# $`svn rev`
# [1] "76782"
#
# $language
# [1] "R"
#
# $version.string
# [1] "R version 3.6.1 (2019-07-05)"
#
# $nickname
# [1] "Action of the Toes"

# %%
# install & load necessary packages

# install.packages(c('mvtnorm','clusterGeneration'))
library(mvtnorm) # will use rmvnorm function from this package
library(clusterGeneration) # will use rcorrmatrix function from this package
# Out:
# Loading required package: MASS
# Warning message:
# “package ‘MASS’ was built under R version 3.6.3”

# %%
# what does rmvnorm do?

?rmvnorm
# Out:
# Mvnorm                 package:mvtnorm                 R Documentation
#
# s
#
# n:
#
#      These functions provide the density function and a random number
#      generator for the multivariate normal distribution with mean equal
#      to ‘mean’ and covariance matrix ‘sigma’.
#
# e:
#
#      dmvnorm(x, mean = rep(0, p), sigma = diag(p), log = FALSE, checkSymmetry = TRUE)
#      rmvnorm(n, mean = rep(0, nrow(sigma)), sigma = diag(length(mean)),
#              method=c("eigen", "svd", "chol"), pre0.9_9994 = FALSE, checkSymmetry = TRUE)
#
# s:
#
#        x: vector or matrix of quantiles. If ‘x’ is a matrix, each row
#           is taken to be a quantile.
#
#        n: number of observations.
#
#     mean: mean vector, default is ‘rep(0, length = ncol(x))’.
#
#    sigma: covariance matrix, default is ‘diag(ncol(x))’.
#
#      log: logical; if ‘TRUE’, densities d are given as log(d).
#
#   method: string specifying the matrix decomposition used to determine
# ...

# %%
# what does rcorrmatrix do?

?rcorrmatrix
# Out:
# rcorrmatrix         package:clusterGeneration          R Documentation
#
# L
# S
#
# n:
#
#      Generate a random correlation matrix based on random partial
#      correlations.
#
# e:
#
#        rcorrmatrix(d, alphad = 1)
#
# s:
#
#        d: Dimension of the matrix. ‘d’ should be a non-negative
#           integer.
#
#   alphad: alpha parameter for partial of 1,d given 2,...,d-1, for
#           generating random correlation matrix based on the method
#           proposed by Joe (2006), where d is the dimension of the
#           correlation matrix. The default value ‘alphad’=1 leads to a
#           random matrix which is uniform over space of positive
#           definite correlation matrices. Each correlation has a
#           Beta(a,a) distribution on (-1,1) where a=alphad+(d-2)/2.
#           ‘alphad’ should be a positive number.
#
# e:
#
#      A correlation matrix.
#
# s):
#
#      Weiliang Qiu <email: weiliang.qiu@gmail.com>
#      Harry Joe <email: harry@stat.ubc.ca>
#
# ...
